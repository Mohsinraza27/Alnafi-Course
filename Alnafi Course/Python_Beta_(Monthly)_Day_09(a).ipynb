# %% [markdown]
# # Requests Module

# %%
import requests

# %%
x = requests.get("https://facebook.com/")
print(x)
# Out:
# <Response [200]>

# %%
print(x.status_code)
# Out:
# 200

# %%
print(x.text)
# Out:
# <!DOCTYPE html>
# <html lang="ur" id="facebook" class="no_js">
# ...

# %%
print(x.headers)
# Out:
# {'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Set-Cookie': 'fr=0Qpn6N9gmme9paGxR..BiC5yF.g8.AAA.0.0.BiC5yF.AWWnRiTIXhY; expires=Mon, 16-May-2022 12:28:52 GMT; Max-Age=7775999; path=/; domain=.facebook.com; secure; httponly, sb=hZwLYirNP2b1o7JjRkry4Y1J; expires=Thu, 15-Feb-2024 12:28:53 GMT; Max-Age=63072000; path=/; domain=.facebook.com; secure; httponly', 'report-to': '{"max_age":3600,"endpoints":[{"url":"https:\\/\\/www.facebook.com\\/ajax\\/browser_error_reports\\/?device_level=unknown"}],"group":"network-errors"}', 'nel': '{"report_to":"network-errors","max_age":3600,"failure_fraction":0.01}', 'x-fb-rlafr': '0', 'document-policy': 'force-load-at-top', 'Pragma': 'no-cache', 'Cache-Control': 'private, no-cache, no-store, must-revalidate', 'Expires': 'Sat, 01 Jan 2000 00:00:00 GMT', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'X-Frame-Options': 'DENY', 'Strict-Transport-Security': 'max-age=15552000; preload', 'Content-Type': 'text/html; charset="utf-8"',
# ...

# %%
import requests

x = requests.head("https://facebook.com/")
print(x.headers)
print(x.headers['Content-Type'])
# Out:
# {'Location': 'https://www.facebook.com/', 'Access-Control-Expose-Headers': 'X-FB-Debug, X-Loader-Length', 'Access-Control-Allow-Methods': 'OPTIONS', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Origin': 'https://facebook.com', 'Vary': 'Origin', 'Strict-Transport-Security': 'max-age=15552000; preload', 'Content-Type': 'text/html; charset="utf-8"', 'X-FB-Debug': 'HTPw/vX1kUxKKc4tKhTfl/JEBZqBMtmIL7hR5IirwAawxYki5A+AoDYNEQMgcj66N4adj1pNwKwUwtS4rwWE5g==', 'Date': 'Tue, 15 Feb 2022 12:34:21 GMT', 'Priority': 'u=3,i', 'Alt-Svc': 'h3=":443"; ma=3600, h3-29=":443"; ma=3600', 'Connection': 'keep-alive', 'Content-Length': '0'}
# text/html; charset="utf-8"

# %%
res = requests.get("https://www.facebook.com/?_rdc=2&_rdr")
print(res)
# Out:
# <Response [200]>

# %%
print(res.status_code)
# Out:
# 200

# %%
data_1 = res.headers

# %%
data_1
# Out:
# {'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Set-Cookie': 'fr=0o5rA9P2GU3OI0GQW..BiC56T.GM.AAA.0.0.BiC56T.AWXynCN-1us; expires=Mon, 16-May-2022 12:37:38 GMT; Max-Age=7775999; path=/; domain=.facebook.com; secure; httponly, sb=k54LYhRyeuvTG3iw349Oys7U; expires=Thu, 15-Feb-2024 12:37:39 GMT; Max-Age=63072000; path=/; domain=.facebook.com; secure; httponly', 'report-to': '{"max_age":3600,"endpoints":[{"url":"https:\\/\\/www.facebook.com\\/ajax\\/browser_error_reports\\/?device_level=unknown"}],"group":"network-errors"}', 'nel': '{"report_to":"network-errors","max_age":3600,"failure_fraction":0.01}', 'x-fb-rlafr': '0', 'document-policy': 'force-load-at-top', 'Pragma': 'no-cache', 'Cache-Control': 'private, no-cache, no-store, must-revalidate', 'Expires': 'Sat, 01 Jan 2000 00:00:00 GMT', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'X-Frame-Options': 'DENY', 'Strict-Transport-Security': 'max-age=15552000; preload', 'Content-Type': 'text/html; charset="utf-8"',
# ...

# %%
res_1 = requests.get("https://api.github.com/users/sana-rasheed")
print(res_1)
# Out:
# <Response [200]>

# %%
data
# Out:
# {'login': 'Sana-Rasheed',
#  'id': 7486141,
#  'node_id': 'MDQ6VXNlcjc0ODYxNDE=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/7486141?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Sana-Rasheed',
#  'html_url': 'https://github.com/Sana-Rasheed',
#  'followers_url': 'https://api.github.com/users/Sana-Rasheed/followers',
#  'following_url': 'https://api.github.com/users/Sana-Rasheed/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Sana-Rasheed/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Sana-Rasheed/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Sana-Rasheed/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Sana-Rasheed/orgs',
#  'repos_url': 'https://api.github.com/users/Sana-Rasheed/repos',
#  'events_url': 'https://api.github.com/users/Sana-Rasheed/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Sana-Rasheed/received_events',
# ...

# %%
data = res_1.json()

# %%
print("Following: ", data['following'])
# Out:
# Following:  1

# %%
print("Followers: ", data['followers'])
# Out:
# Followers:  209

# %%
print("publc_repos: ", data['public_repos'])
# Out:
# publc_repos:  43

# %%
print("publc_gists: ", data['public_gists'])
# Out:
# publc_gists:  2

# %%
print("created_at: ", data['created_at'])
# Out:
# created_at:  2014-05-05T08:01:36Z

# %%
print("updated_at: ", data['updated_at'])
# Out:
# updated_at:  2022-01-28T16:32:45Z

# %%
import requests

# %%
## api-endpoint

url = "https://github.com/Sarah-Mashhood"
response = requests.get(url)

# %%
print(url)
# Out:
# https://github.com/Sarah-Mashhood

# %%
print(response)
# Out:
# <Response [200]>

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-31-34c975fa6377> in <module>
# ----> 1 response.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# ...

# %%
exer = requests.get("https://www.google.com")

# %%
exer
# Out:
# <Response [200]>

# %%
print(exer.status_code)
# Out:
# 200

# %%
print(exer.text)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-PK"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="LJWfJu0XvLgRkOuRUcsOzw==">(function(){window.google={kEI:'JJUMYoSvD5eFhbIP4ZyBOA',kEXPI:'0,1302536,56873,1709,4349,207,4804,926,1390,383,246,5,1354,4013,1237,1122516,1197713,681,36,380060,16115,17444,11240,17572,4859,1361,9290,3026,17583,4020,978,13226,3849,4192,6430,14763,7979,6673,1279,2453,289,149,1103,840,1986,211,4100,108,3406,606,2023,2297,14670,3227,2845,7,4773,12677,8102,3522,4697,907,2,3555,13142,3,576,1014,1,5444,149,11323,2652,4,1528,2304,6463,576,20309,4764,2658,7357,30,13628,2305,2132,16786,5806,2551,4094,4052,3,3541,1,16807,38,6868,18441,2,15953,784,255,4550,126,618,5852,10463,1160,5679,1020,2378,2721,18233,64,2,6,1,7718,2123,2444,2578,2788,890,2963,3757,16701,830,422,4570,2,6,1,1256,1220
# ...

# %%
print(exer.history)
# Out:
# []

# %%
print(exer.headers)
# Out:
# {'Date': 'Wed, 16 Feb 2022 06:09:40 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '1P_JAR=2022-02-16-06; expires=Fri, 18-Mar-2022 06:09:40 GMT; path=/; domain=.google.com; Secure, NID=511=iwyRyQfbqSqtySLkbMHkLOw3FFWWruLPH7OUhDvLM5lZWsbDFV9R8VkCMOiAVhtUX9-ZXeSLphSU9gy_lbnnxFe77q6y-ZSJzEzVmQEUfU8HBhS7FsyhOygWjcbXfpDUpwz5mveN1c6qUa0nvek_dmAR20hgDSw-yqSRWMkW-WY; expires=Thu, 18-Aug-2022 06:09:40 GMT; path=/; domain=.google.com; HttpOnly', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000,h3-Q050=":443"; ma=2592000,h3-Q046=":443"; ma=2592000,h3-Q043=":443"; ma=2592000,quic=":443"; ma=2592000; v="46,43"', 'Transfer-Encoding': 'chunked'}

# %%
pr = exer.json

# %%
pr
# Out:
# <bound method Response.json of <Response [200]>>

# %%
pr = exer.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-65-120283177066> in <module>
# ----> 1 pr = exer.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# ...

# %%
import requests

# %%
myobj = [('ali', 45), ('ahmed', 34), ('amna', 52)]

# %%
r = requests.post("https://httpbin.org/post", data=myobj)

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "ahmed": "34", \n    "ali": "45", \n    "amna": "52"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "23", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.25.1", \n    "X-Amzn-Trace-Id": "Root=1-620c9791-09ecc81140616bc63ffa5320"\n  }, \n  "json": null, \n  "origin": "182.189.215.124", \n  "url": "https://httpbin.org/post"\n}\n'

# %%
r.headers
# Out:
# {'Date': 'Wed, 16 Feb 2022 06:20:01 GMT', 'Content-Type': 'application/json', 'Content-Length': '518', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
data=r.json()

# %%
data
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'ahmed': '34', 'ali': '45', 'amna': '52'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '23',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.25.1',
#   'X-Amzn-Trace-Id': 'Root=1-620c9791-09ecc81140616bc63ffa5320'},
#  'json': None,
#  'origin': '182.189.215.124',
#  'url': 'https://httpbin.org/post'}

# %%
data['origin']
# Out:
# '182.189.215.124'

# %%
idi = requests.get("https://www.instagram.com/mohsinraza1770/")

# %%
idi
# Out:
# <Response [200]>

# %%
idi.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" class="no-js not-logged-in client-root">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n        <title>\nMohsin Tariq (@mohsinraza1770) • Instagram photos and videos\n</title>\n\n        \n        <meta name="robots" content="noimageindex, noarchive">\n        <meta name="apple-mobile-web-app-status-bar-style" content="default">\n        <meta name="mobile-web-app-capable" content="yes">\n        <meta name="theme-color" content="#ffffff">\n        <meta id="viewport" name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, viewport-fit=cover">\n        <link rel="manifest" href="/data/manifest.json">\n\n        <link rel="preload" href="/static/bundles/metro/ConsumerUICommons.css/544e6e029d31.css" as="style" type="text/css" crossorigin="anonymous" />\n<link rel="preload" href="/static/bundles/metro/Consumer.css/bc96d5aeac03.css" as="style" type="tex
# ...

# %%
idi.headers
# Out:
# {'Content-Type': 'text/html; charset=utf-8', 'Vary': 'Accept-Language, Cookie, Accept-Encoding', 'Content-Language': 'en', 'Date': 'Wed, 16 Feb 2022 06:27:26 GMT', 'Content-Encoding': 'gzip', 'Strict-Transport-Security': 'max-age=31536000', 'Cache-Control': 'private, no-cache, no-store, must-revalidate', 'Pragma': 'no-cache', 'Expires': 'Sat, 01 Jan 2000 00:00:00 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'content-security-policy': "report-uri https://www.instagram.com/security/csp_report/; default-src 'self' https://www.instagram.com; img-src data: blob: https://*.fbcdn.net https://*.instagram.com https://*.cdninstagram.com https://*.facebook.com https://*.fbsbx.com https://*.giphy.com; font-src data: https://*.fbcdn.net https://*.instagram.com https://*.cdninstagram.com; media-src 'self' blob: https://www.instagram.com https://*.cdninstagram.com https://*.fbcdn.net; manifest-src 'self' https://www.instagram.com; script-src 'self' https://instagram.com https://www.instagram.com https://
# ...

# %%
idi.history
# Out:
# []

# %%
idi.status_code
# Out:
# 200

# %%
idi.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
idi.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-73-8cbba147c965> in <module>
# ----> 1 idi.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# ...
